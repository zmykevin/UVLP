# %%
import numpy as np
import json
import os
import os.path as op
import logging
from tqdm import tqdm
from numba import jit

# %%
class TSVFile(object):
    def __init__(self, tsv_file, generate_lineidx=False):
        self.tsv_file = tsv_file
        self.lineidx = op.splitext(tsv_file)[0] + '.lineidx'
        self._fp = None
        self._lineidx = None
        # the process always keeps the process which opens the file. 
        # If the pid is not equal to the currrent pid, we will re-open the file.
        self.pid = None
        # generate lineidx if not exist
        if not op.isfile(self.lineidx) and generate_lineidx:
            generate_lineidx_file(self.tsv_file, self.lineidx)

    def __del__(self):
        if self._fp:
            self._fp.close()

    def __str__(self):
        return "TSVFile(tsv_file='{}')".format(self.tsv_file)

    def __repr__(self):
        return str(self)

    def num_rows(self):
        self._ensure_lineidx_loaded()
        return len(self._lineidx)

    def seek(self, idx):
        self._ensure_tsv_opened()
        self._ensure_lineidx_loaded()
        try:
            pos = self._lineidx[idx]
        except:
            logging.info('{}-{}'.format(self.tsv_file, idx))
            raise
        self._fp.seek(pos)
        return [s.strip() for s in self._fp.readline().split('\t')]

    def seek_first_column(self, idx):
        self._ensure_tsv_opened()
        self._ensure_lineidx_loaded()
        pos = self._lineidx[idx]
        self._fp.seek(pos)
        return read_to_character(self._fp, '\t')

    def __getitem__(self, index):
        return self.seek(index)

    def __len__(self):
        return self.num_rows()

    def _ensure_lineidx_loaded(self):
        if self._lineidx is None:
            logging.info('loading lineidx: {}'.format(self.lineidx))
            with open(self.lineidx, 'r') as fp:
                self._lineidx = [int(i.strip()) for i in fp.readlines()]

    def _ensure_tsv_opened(self):
        if self._fp is None:
            self._fp = open(self.tsv_file, 'r')
            self.pid = os.getpid()

        if self.pid != os.getpid():
            logging.info('re-open {} because the process id changed'.format(self.tsv_file))
            self._fp = open(self.tsv_file, 'r')
            self.pid = os.getpid()

def sort_objects(raw_objects, img_h=None, img_w = None):
    #Return two list, one without considering the order but value the counts, the other consider the order of the objects
    
    #Design a mechanism to sort objects
    confidence_low = 0.3
    dimension_ratio = 0.01
    
    #Score or filtering?
    filtered_objects = {}
    filtered_objects_list = []
    for x in raw_objects:
        x_class = x['class']
        x_conf = x['conf']
        x_h = x['rect'][2]-x['rect'][0]
        x_w = x['rect'][3]-x['rect'][1]
        x_ratio = (x_h*x_w)/(img_h*img_w)
        if x_conf >= confidence_low and x_ratio >=dimension_ratio:
            if filtered_objects.get(x_class, None) is None:
                filtered_objects[x_class] = {"conf": [x_conf], "size_ratio":[x_ratio]}
            else:
                filtered_objects[x_class]["conf"].append(x_conf)
                filtered_objects[x_class]["size_ratio"].append(x_ratio)
            filtered_objects_list.append(x_class)
    #print(filtered_objects)
    #print(filtered_objects), sort by size and count
#     sort_count_objects = {k:v for k,v in sorted(filtered_objects.items(), key=lambda item: len(item[1]['conf']))}
#     sort_ratio_objects = {k:v for k,v in sorted(filtered_objects.items(), key=lambda item: max(item[1]['size_ratio']))} 
    
#     print(sort_count_objects)
#     print(sort_ratio_objects)
    
    total_counts = 0
    for v in filtered_objects.values():
        total_counts += len(v['conf'])
        
    #Now score the obejects
#     objects_count_score = {k:len(v['conf'])/total_counts*10 for k,v in filtered_objects.items()}
#     objects_ratio_score = {k:max(v['size_ratio'])*10 for k,v in filtered_objects.items()}
    sorted_objects = []
    for k,v in filtered_objects.items():
        current_count_score = len(v['conf'])/total_counts*10
        current_size_ratio_score = max(v['size_ratio'])*10
        sorted_objects.append((k, current_count_score+current_size_ratio_score))
    filtered_sorted_objects = [y[0] for y in sorted(sorted_objects, key=lambda x: x[1], reverse=True)]
    
    
    return filtered_objects_list, filtered_sorted_objects

# %%
#Get the Annotation Data
annotation = "/data/home/zmykevin/vinvl_data/CC/model_0060000/annotations/0/dataset_cc.json"
annotation_data = json.load(open(annotation, "r"))

# %%
#Get the object Info
cc_objects_captions = {}
id_range = [x for x in range(12)]
for id_ in id_range: 
    print("Create the features for chunk {}".format(id_))
    #Lets load the VinVL Features
    coco_vinvl_path = "/data/home/zmykevin/vinvl_data/CC/model_0060000/{}".format(id_)
    coco_vinvl_prediction_tsv = TSVFile(os.path.join(coco_vinvl_path, "predictions.tsv"))
    num_rows = coco_vinvl_prediction_tsv.num_rows()
    
    for i in tqdm(range(num_rows)):
        current_prediction = coco_vinvl_prediction_tsv.seek(i)
        #print(current_prediction)
        img_id = int(current_prediction[0])
        #print(img_id)
        #get object list
        #objects = [x['class'] for x in json.loads(current_prediction[1])['objects']]
        current_info = json.loads(current_prediction[1])
        raw_objects = current_info['objects']
        objects, objects_no_rep = sort_objects(raw_objects, current_info['image_h'], current_info['image_w']) 
        #print(objects)
        cc_objects_captions[img_id] = {"objects": " ".join(objects), "objects_no_rep": " ".join(objects_no_rep)}
# Out:
#   0%|          | 757/259957 [00:00<00:34, 7566.69it/s]
# Create the features for chunk 0
# 100%|██████████| 259957/259957 [00:36<00:00, 7133.61it/s]
#   0%|          | 0/259795 [00:00<?, ?it/s]
# Create the features for chunk 1
# 100%|██████████| 259795/259795 [00:36<00:00, 7164.16it/s]
#   0%|          | 0/259835 [00:00<?, ?it/s]
# Create the features for chunk 2
# 100%|██████████| 259835/259835 [00:37<00:00, 6988.18it/s]
#   0%|          | 0/259914 [00:00<?, ?it/s]
# Create the features for chunk 3
# 100%|██████████| 259914/259914 [00:42<00:00, 6161.63it/s]
#   0%|          | 0/259908 [00:00<?, ?it/s]
# Create the features for chunk 4
# 100%|██████████| 259908/259908 [00:43<00:00, 5921.82it/s]
#   0%|          | 0/259632 [00:00<?, ?it/s]
# Create the features for chunk 5
# 100%|██████████| 259632/259632 [00:45<00:00, 5714.18it/s]
#   0%|          | 0/259496 [00:00<?, ?it/s]
# Create the features for chunk 6
# 100%|██████████| 259496/259496 [00:46<00:00, 5546.71it/s]
# Create the features for chunk 7
# 100%|██████████| 259436/259436 [00:46<00:00, 5590.52it/s]
#   0%|          | 0/259596 [00:00<?, ?it/s]
# Create the features for chunk 8
# 100%|██████████| 259596/259596 [00:44<00:00, 5806.42it/s]
# Create the features for chunk 9
# 100%|██████████| 259589/259589 [00:44<00:00, 5795.56it/s]
#   0%|          | 0/259750 [00:00<?, ?it/s]
# Create the features for chunk 10
# 100%|██████████| 259750/259750 [00:46<00:00, 5633.09it/s]
#   0%|          | 0/259346 [00:00<?, ?it/s]
# Create the features for chunk 11
# 100%|██████████| 259346/259346 [00:44<00:00, 5782.67it/s]

# %%
for x in annotation_data['images']:
    img_id = x['imgid']
    caption = x['sentences'][0]['raw']
    if cc_objects_captions.get(img_id, None) is not None:
        cc_objects_captions[img_id]['caption'] = caption

# %%
#print(len(cc_objects_captions))
with open("/data/home/zmykevin/vinvl_data/CC/cc_objects_captions_sorted.json", "w") as f:
    json.dump(cc_objects_captions, f)

# %%
with open("/data/home/zmykevin/vinvl_data/CC/cc_objects_captions_sorted.json", "r") as f:
    cc_objects_captions = json.load(f)

print("finish loading the captions")
# Out:
# finish loading the captions

# %%
# object_rep_list = [x['objects_no_rep'] for x in cc_objects_captions]
# caption_list = [x['caption'] for x in cc_objects_captions]
id_list = []
object_list = []
caption_list = []
for k, v in cc_objects_captions.items():
    id_list.append(k)
    object_list.append(v['objects_no_rep'])
    caption_list.append(v['caption'])
#     break
# print(id_list)
# print(object_rep_list)
# print(caption_list)

# %%
all_list = object_list + caption_list

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Create TfidfVectorizer object
vectorizer = TfidfVectorizer()

# Generate matrix of word vectors
tfidf_matrix = vectorizer.fit_transform(all_list)

# %%
#Save this tfidf_matrix
# with open('/data/home/zmykevin/vinvl_data/CC/CC_tfidf.npy', 'rb') as f:
#     tfidf_matrix=np.load(f, allow_pickle=True)

# %%
print(tfidf_matrix.shape)
# Out:
# (6232508, 46246)

# %%
object_tfidf = tfidf_matrix[:3116254]
caption_tfidf = tfidf_matrix[3116254:]

# %%
# del tfidf_matrix
from sklearn.metrics.pairwise import cosine_similarity
# from scipy import sparse
from scipy.sparse import csr_matrix
import sparse_dot_topn.sparse_dot_topn as ct


def awesome_cossim_top(A, B, ntop, lower_bound=0):
    # force A and B as a CSR matrix.
    # If they have already been CSR, there is no overhead
    A = A.tocsr()
    B = B.tocsr()
    M, _ = A.shape
    _, N = B.shape
 
    idx_dtype = np.int32
 
    nnz_max = M*ntop
 
    indptr = np.zeros(M+1, dtype=idx_dtype)
    indices = np.zeros(nnz_max, dtype=idx_dtype)
    data = np.zeros(nnz_max, dtype=A.dtype)

    ct.sparse_dot_topn(
        M, N, np.asarray(A.indptr, dtype=idx_dtype),
        np.asarray(A.indices, dtype=idx_dtype),
        A.data,
        np.asarray(B.indptr, dtype=idx_dtype),
        np.asarray(B.indices, dtype=idx_dtype),
        B.data,
        ntop,
        lower_bound,
        indptr, indices, data)

    return csr_matrix((data,indices,indptr),shape=(M,N))

# %%
import time
import csv
# t1 = time.time()
# #cosine_sim = cosine_similarity(object_tfidf[:1000], caption_tfidf)
# cosine_sim = awesome_cossim_top(object_tfidf[:10], caption_tfidf.T, 10, 0.1)
# print(time.time() - t1)
def save_csv(visualization, output_path):
    csv_columns = ['original_id', "original_obj", "original_caption", "retrieved_1", "retrieved_2", "retrieved_3"]
    with open(output_path, "w") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in visualization:
            writer.writerow(data)
    
def save_json(closest_captions, output_path):
    with open(output_path, "w") as f:
        json.dump(closest_captions, f)
    
def load_csv(csv_path):
    loaded_data = []
    with open(csv_path, "r") as csv_file:
        csv_reader = csv.reader(csv_file,delimiter=',')
        for i, row in enumerate(csv_reader):
            if i == 0:
                header_info = row
            else:
                current_data_point = {}
                for j, x in enumerate(row):
                    current_data_point[header_info[j]] = x
                loaded_data.append(current_data_point)
    return loaded_data

batch_size = 1000
save_checkpoint = 100000
#closest_captions = {}
# visualization = []
output_path = "/data/home/zmykevin/vinvl_data/CC"
closest_captions = json.load(open(os.path.join(output_path, "captions_retrieved.json"),"r"))
visualization = load_csv(os.path.join(output_path, "captions_retrieved.csv"))
starting_index = len(visualization)
error_ids = []

checkpoint_index = 0
for i in tqdm(range(starting_index,caption_tfidf.shape[0], batch_size)):
    valid_batch_size = batch_size if i+batch_size < caption_tfidf.shape[0] else caption_tfidf.shape[0]-i
    cosine_sim = awesome_cossim_top(object_tfidf[i:i+valid_batch_size], caption_tfidf.T, 10, -1)
    non_zeros = cosine_sim.nonzero()
    sparserows = non_zeros[0]
    sparsecols = non_zeros[1]
    
    for index in range(valid_batch_size):
        try:
            original_id = id_list[index + i]
            right_side = [id_list[x] for x in sparsecols[index*10:index*10+10]]
            current_output = {}
            current_output['original_id'] = original_id
            current_output['original_obj'] = cc_objects_captions[original_id]['objects_no_rep']
            current_output['original_caption'] = cc_objects_captions[original_id]['caption']
            current_output['retrieved_1'] = cc_objects_captions[right_side[0]]['caption']
            current_output['retrieved_2'] = cc_objects_captions[right_side[1]]['caption']
            current_output['retrieved_3'] = cc_objects_captions[right_side[2]]['caption']
            #store the other info into json
            closest_captions[original_id] =right_side
            visualization.append(current_output)
        except:
            print("The bug occurs at {}".format(i+index))
            print("The error id is: {}".format(original_id))
            error_ids.append(original_id)
    if int((i+valid_batch_size)/save_checkpoint) > checkpoint_index:
        save_json(closest_captions, os.path.join(output_path, "captions_retrieved_backup.json")) 
        save_csv(visualization, os.path.join(output_path, "captions_retrieved_backup.csv"))
        save_json(error_ids, os.path.join(output_path, "captions_retrieved_error_ids.json"))
        checkpoint_index +=1
#Store the information to csv and json
output_path = "/data/home/zmykevin/vinvl_data/CC"
#save the json file

save_json(closest_captions, os.path.join(output_path, "captions_retrieved.json"))   
#save the csv file
save_csv(visualization, os.path.join(output_path, "captions_retrieved.csv"))
save_json(error_ids, os.path.join(output_path, "captions_retrieved_error_ids.json"))
# Out:
#   0%|          | 4/2217 [01:50<16:59:15, 27.63s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-b0f7ab000067> in <module>
#      44 for i in tqdm(range(starting_index,caption_tfidf.shape[0], batch_size)):
#      45     valid_batch_size = batch_size if i+batch_size < caption_tfidf.shape[0] else caption_tfidf.shape[0]-i
# ---> 46     cosine_sim = awesome_cossim_top(object_tfidf[i:i+valid_batch_size], caption_tfidf.T, 10, -1)
#      47     non_zeros = cosine_sim.nonzero()
#      48     sparserows = non_zeros[0]
#
# <ipython-input-9-4c0bb6f882a8> in awesome_cossim_top(A, B, ntop, lower_bound)
#      31         ntop,
#      32         lower_bound,
# ---> 33         indptr, indices, data)
#      34
#      35     return csr_matrix((data,indices,indptr),shape=(M,N))
#
# KeyboardInterrupt:

# %%
print(cosine_sim.shape)

# %%
retrieved_image_id = id_list[3110513]
print(retrieved_image_id)
# Out:
# 3327912

# %%
print(cc_objects_captions[str(3)])
print(cc_objects_captions[retrieved_image_id])
# Out:
# {'objects': 'fireplace floor ceiling shadow letter wall wall building light ledge fire room bar log brick wall wall brick wall desk light sign word letter wall bench tile', 'objects_no_rep': 'floor ceiling fireplace building room bar log desk brick word shadow ledge fire sign tile letter bench wall light', 'caption': 'interior design of modern living room with fireplace in a new house'}
# {'objects': 'fire fire fire fire fire log fireplace sky fire letter fire wire word rock log cable letter rock', 'objects_no_rep': 'fireplace log fire cable letter sky rock wire word', 'caption': 'log on fire in a fireplace'}

# %%
# Out:
# 0
# {'objects': 'bus bus bus bus building bus bus building shirt man shirt person road shirt person person person person man car man man person man bus person bus door person person person person pant person bus person window window person street person window man bus shirt man roof man man shirt person person boat hat balcony van pant bus sign roof', 'objects_no_rep': 'pant street building shirt man person hat car roof sign door van window road balcony boat bus', 'caption': 'a very typical bus station'}
# 1
# {'objects': 'drum drum hair microphone dress man drum person woman face shoe shirt person leg hand drum wall shoe woman skirt girl shirt leg poster dress woman leg person arm person picture person tripod neck top', 'objects_no_rep': 'man neck wall woman shirt skirt face top shoe arm person poster hand girl dress tripod drum hair leg picture microphone', 'caption': 'sierra looked stunning in this top and this skirt while performing with person at their former university'}
# 2
# {'objects': 'jean cabinet closet floor cabinet clothes shirt clothes hanger tub woman closet floor clothes clothes piano shirt window cabinet shirt bathtub scarf fence hand handle pillow girl door shirt rug hair bag clothing hand hair drawer clothes shirt clothes glasses', 'objects_no_rep': 'bathtub scarf pillow glasses hanger handle jean woman shirt bag clothing window floor hand girl closet clothes piano tub door rug drawer fence hair cabinet', 'caption': 'young confused girl standing in front of a wardrobe'}
# 3
# {'objects': 'fireplace floor ceiling shadow letter wall wall building light ledge fire room bar log brick wall wall brick wall desk light sign word letter wall bench tile', 'objects_no_rep': 'floor ceiling fireplace building room bar log desk brick word shadow ledge fire sign tile letter bench wall light', 'caption': 'interior design of modern living room with fireplace in a new house'}
# 4
# {'objects': 'sky leg string leg leg letter leg boot boot boot word handlebar boot handlebar sky letter letter handle foot', 'objects_no_rep': 'string word foot handle letter handlebar sky leg boot', 'caption': 'cybernetic scene isolated on white background .'}
# 5
# {'objects': 'man bottle bottle hand chair shoe shirt necklace bottle man woman hair hand boot shoe head hat pant bracelet boy shirt chain watch hair person man chair logo jacket floor logo chair bottle finger line necklace bench lid hand boot letter person shirt earring hair suit hand seat label man jean man', 'objects_no_rep': 'man bench finger logo chain jean woman pant boy shirt jacket letter lid watch chair shoe necklace floor label person hand bracelet suit line bottle seat head hat earring hair boot', 'caption': 'gangsta rap artist attends sports team vs playoff game in the borough .'}
# 6
# {'objects': 'flower ball tree person shirt tree flower pole man person person person person person flower bush man person bench pole pant bush building person person man flower person child flower', 'objects_no_rep': 'pant tree building flower shirt person man child bench ball pole bush', 'caption': 'the jetty : different types of plants to establish a variety of ecosystems .'}
# 7
# {'objects': 'flower flower flower flower flower sun flower flower heart flower face heart heart sun heart heart design heart board light dot wing heart face', 'objects_no_rep': 'flower sun design heart face board dot wing light', 'caption': 'traditional ornamental floral paisley bandanna .'}
# 8
# {'objects': 'helmet sock glove glove man woman logo shoe wall head pole pole shoe pole person leg hand number uniform person number person hair chair strap seat stand chair person jersey person jacket ground person person pant snow nose foot person person neck', 'objects_no_rep': 'man pole logo neck wall glove woman pant jacket chair ground shoe helmet snow person hand foot nose uniform stand seat number head jersey hair leg strap sock', 'caption': '# of the sports team skates against sports team during their game .'}
# 10
# {'objects': 'airplane car car tail dirt car car sign van sky parking lot car truck pole sign light car car runway jeep pole fuselage pole road car car van car van car car ground wing airport pole car street light car car wheel truck parking lot car car field runway car road pole parking lot engine car wheel car car', 'objects_no_rep': 'engine fuselage airplane pole jeep runway street light field wheel car ground road tail airport sign dirt van sky parking lot light truck wing', 'caption': 'a flight was traveling when the animal got free on tuesday night'}
# 11
# {'objects': 'boot boot boot boot pant hair pant hair boot man sky jean hair boot glove shirt tree head ponytail leaf leaf woman tree arm sweater leaf tree person shirt person glove ground person leaf tree boot woman head tree girl cap tree sky head leaf tree field sweater leaf leaf glove glove woman leaf sweatshirt tree dirt person leaf tree jacket', 'objects_no_rep': 'man sweater jean glove woman pant field shirt jacket ponytail ground arm leaf person girl dirt cap sky tree head sweatshirt hair boot', 'caption': 'even though agricultural conditions are not ideal for growing tobacco , there is indigenous production .'}
# 13
# {'objects': 'glasses man hair beard man eye logo nose jacket eyebrow head mouth face mustache eye ear ear sign logo word forehead suit wall poster logo pocket logo', 'objects_no_rep': 'pocket man glasses eyebrow logo mouth wall jacket face beard forehead poster ear nose sign suit mustache head eye hair word', 'caption': 'actor arrives for the premiere of the film'}
# 14
# {'objects': 'air conditioner christmas tree man pillow flower floor ornament curtain dress couch ornament hair floor christmas tree wall rug shirt girl shoe woman ornament pillow girl rug shoe hair boy sandal sofa tree head chair girl purse child child pant carpet head flag family person ground sweater hand flower building pot baby shoe head sleeve head ceiling face dress', 'objects_no_rep': 'air conditioner pot man pillow sweater sandal wall family woman pant carpet flag boy flower shirt ornament face sofa chair ground shoe purse couch floor ceiling building person hand girl dress tree baby head sleeve rug christmas tree child hair curtain', 'caption': 'celebrities start decorating for the christmas season lifestyle'}
# 15
# {'objects': 'building flag poster dome window pillar building pillar fence balcony stripe', 'objects_no_rep': 'flag building stripe poster fence window pillar balcony dome', 'caption': 'functions of government : 1 . form a more perfect union'}
# 16
# {'objects': 'woman hair shirt ear arm eye eye lip wall nose earring face eyebrow neck dress arm shirt head smile lipstick tank top', 'objects_no_rep': 'lipstick lip shirt head ear nose eye face earring eyebrow neck hair tank top smile wall dress arm woman', 'caption': 'actor attends the premiere of season'}
# 19
# {'objects': 'shirt sky cloud cloud person bike cloud cloud mountain person man person person person person shirt bicycle person person person person tire boy helmet bicycle tree mountain pole hat person shirt helmet helmet wheel bicycle helmet helmet ground wheel flag helmet cloud cloud tire hat tire helmet bike tree group person bicycle person helmet sign gravel pole flag bike helmet man', 'objects_no_rep': 'group tree tire boy shirt wheel flag person man bicycle mountain hat sign pole sky ground helmet bike cloud gravel', 'caption': 'all shots by by person and rider shots can be found on his website .'}
# 20
# {'objects': 'deer flower ear flower mouth nose grass leg flower flower leg eye animal tree animal head leg', 'objects_no_rep': 'tree flower head ear nose eye grass mouth deer leg animal', 'caption': 'photo of a deer and wildfire'}
# 21
# {'objects': 'shirt laptop man button mouth tie keyboard nose hand hand eye ear shirt hair head paper collar cabinet computer thumb book face door wall thumb arm key finger hand teeth knot touchpad person envelope cabinet paper', 'objects_no_rep': 'computer man thumb finger laptop mouth knot wall book shirt face key arm person hand ear nose envelope door keyboard head touchpad button tie eye teeth collar hair cabinet paper', 'caption': 'high angle view of a businessman lying on a table and singing'}
# 22
# {'objects': 'lemon plate leaf lemon food salad lettuce table sandwich meat bread table cabbage leaf lettuce salad', 'objects_no_rep': 'leaf lettuce meat bread salad table lemon plate food sandwich cabbage', 'caption': 'this is real fast food !'}
# 23
# {'objects': 'toy clock table toy dial tile box chimney building table toy roof table box stair fan object plant', 'objects_no_rep': 'building clock chimney tile box roof table plant stair dial object fan toy', 'caption': 'safe deposit with money around it on a white background photo'}
# 24
# {'objects': 'eye ear nose eye giraffe ear chin face rope giraffe fence head mouth rope giraffe rope horn chin nostril fence muzzle spot', 'objects_no_rep': 'chin nostril head ear nose fence eye muzzle face giraffe mouth spot rope horn', 'caption': "the giraffe before he was shot dead then autopsied in the presence of the zoo 's visitors , despite an online petition to save him signed by thousands of animal lovers"}
# 25
# {'objects': 'flag sky tree house sky hill pole road flag tree house roof water tree stream tree grass grass field tree rock tree flag roof grass grass roof building tree house tree hill hill house tree roof house', 'objects_no_rep': 'flag tree field building stream roof pole hill grass sky rock road house water', 'caption': 'dunes lay the blueprint for the back nine .'}
# 26
# {'objects': 'hair chair shirt pillow nose dog woman paw eye face window arm eye ear eye wall couch shirt nose window sofa hand couch letter paw neck mouth head', 'objects_no_rep': 'pillow neck mouth wall woman dog shirt letter face window sofa chair couch arm hand ear nose paw head eye hair', 'caption': 'portrait of a smiling woman stroking her dog lying on couch'}
# 27
# {'objects': 'glasses hair tablet ring hand face woman finger eye hand bench ring arm bench shirt neck lipstick finger nose antenna book jacket finger fence grass hair fence eye woman head laptop suit', 'objects_no_rep': 'glasses bench finger neck laptop book woman shirt jacket tablet face antenna arm hand nose suit ring lipstick head fence eye grass hair', 'caption': 'young business woman on a bench'}
# 28
# {'objects': 'helmet football glove sock helmet helmet shoe sock shoe pant shoe man hat person hat man person person person jersey grass field person helmet person person person line man person person person person hat jacket person player person flag sneaker person crowd person shoe pant', 'objects_no_rep': 'pant flag field player jacket sneaker man person hat football shoe grass crowd jersey line helmet glove sock', 'caption': 'american football player looks downfield during the second half of a football game against sports team'}
# 29
# {'objects': 'bridge building building sky water cloud building cloud building dock building window cloud cloud water roof building building cloud building tree cloud building window tree building', 'objects_no_rep': 'building tree roof window sky bridge dock cloud water', 'caption': '... and local people to deliver a new bridge'}
# 30
# {'objects': 'hair woman eye eye nose face neck logo lip necklace mouth arm head wall purse ring eyebrow', 'objects_no_rep': 'lip head nose eye face eyebrow neck hair logo mouth wall ring necklace purse arm woman', 'caption': 'actor arrives to the premiere'}
# 31
# {'objects': 'tail eye eye tail mouth ground face nose whisker cat head bamboo fence ground stripe fur stripe face straw bamboo stick straw kitten stripe', 'objects_no_rep': 'tail bamboo stripe whisker head fur nose fence eye cat face straw kitten mouth stick ground', 'caption': 'funny animals of the week , animal pictures'}
# 33
# {'objects': 'sky sign tree chain building pole pole wall sign tree brick sky branch wall', 'objects_no_rep': 'building tree branch brick sign pole chain sky wall', 'caption': 'the sign promises as much as the glorious blue sky .'}
# 34
# {'objects': 'water light light ceiling sign building letter word water roof', 'objects_no_rep': 'ceiling building sign roof letter word water light', 'caption': 'architectural details of a bridge'}
# 35
# {'objects': 'tree building building shirt sign person building sky shirt shirt cloud bridge cloud shirt jean shirt window hair woman car window man building wall shirt man person hair man person person person building person person railing person person person hair person purse person building city person bag shirt person woman shirt person woman bag person fire escape hair wall vest backpack person woman woman person building shirt window person person short person short ground window person person person woman man fence cloud woman person sign shirt', 'objects_no_rep': 'man vest jean wall short backpack woman shirt car bag window city ground purse building person railing sign sky fire escape cloud tree fence hair bridge', 'caption': 'people tour and enjoy the public park during summer'}
# 36
# {'objects': 'bottle box tie man dress toy woman dress woman sign head poster floor hand tree shoe hair hair person person building bowl person letter letter carpet toy window wall door necklace window sign', 'objects_no_rep': 'man box wall toy carpet woman letter window shoe necklace floor building poster person hand sign bottle door dress tree head tie hair bowl', 'caption': "interesting 1930 's poster for a cosmetic company with stores ."}
# 37
# {'objects': 'car helmet tire tire tire tire tire wheel wheel window tree rim reflector wheel', 'objects_no_rep': 'tree tire reflector wheel car window helmet rim', 'caption': 'racecar driver steers his car during video game subject .'}
# 38
# {'objects': 'flower flower flower flower leaf petal leaf word wall flower petal flower leaf sign wall petal petal plant leaf letter petal letter flower petal leaf flower leaf word', 'objects_no_rep': 'leaf flower word sign petal plant letter wall', 'caption': 'vintage elegant floral card with frame decorated with black and white lilies on a pink background .'}
# 39
# {'objects': 'snow ground bird snow rock rock snow snow rock snow snow rock', 'objects_no_rep': 'ground bird snow rock', 'caption': 'heavy snow falls over a snow lined river .'}
# 41
# {'objects': 'ear ear hair nose man eye eye shirt button eyebrow collar face lip lip eyebrow wall eyebrow neck man eye mustache head jacket chin chin mouth nostril forehead logo', 'objects_no_rep': 'man eyebrow neck mouth logo wall shirt jacket nostril face forehead lip ear nose mustache chin head button eye collar hair', 'caption': 'pop artist attends the 3rd annual at guest house'}
# 42
# {'objects': 'snowflake sky sign snowflake line snowflake flower line cat star star symbol sky snowflake design circle bird diamond', 'objects_no_rep': 'symbol flower design star sign cat circle line sky snowflake diamond bird', 'caption': 'illustration of a map , its flag and a comic balloon with a soccer ball in a not allowed signal'}
# 43
# {'objects': 'guitar man hand hair microphone watch speaker hand mouth wall jacket ear arm glasses microphone ceiling microphone', 'objects_no_rep': 'ceiling speaker jacket man hand ear glasses watch hair mouth wall guitar arm microphone', 'caption': 'rock artist performs on stage at awards held'}
# 44
# {'objects': 'tail animal tail wing sky wing sky leaf nose head', 'objects_no_rep': 'leaf tail head nose sky wing animal', 'caption': 'green sea turtle isolated on a white background 3d illustration'}
# 45
# {'objects': 'shirt man cake hat wall window writing band head table nose window banana brick writing mouth cherry arm wall arm cowboy hat brick table face brick strap wall cake hand strawberry ketchup brick brick word', 'objects_no_rep': 'cherry band man brick mouth wall shirt face window arm writing hand nose cake ketchup cowboy hat strawberry head hat table banana word strap', 'caption': 'person , was surprised by the staff'}
# 46
# {'objects': 'flag tree pole sky cloud branch cloud bird branch stripe branch sky branch leaf cloud branch cloud', 'objects_no_rep': 'leaf flag tree branch stripe pole sky cloud bird', 'caption': 'red and white flag on the mast'}
# 47
# {'objects': 'cup man hair shirt number man shirt hair man man person shirt jersey man man person man hand hair person hair short person bracelet hair hair shirt person person man woman man head watch hair hand person crowd person person mouth person mouth cup hand badge beard hand name', 'objects_no_rep': 'shirt head badge man person hand bracelet cup name crowd jersey woman hair watch mouth beard short number', 'caption': 'football player celebrates scoring for football team against football team in the final'}
# 48
# {'objects': 'tire wall car wall mirror wheel wall cord wall wire cord mirror fender arm', 'objects_no_rep': 'tire fender wheel car cord wire wall arm mirror', 'caption': 'concept plug - in hybrid car on display'}
# 49
# {'objects': 'zebra head eye ear mane eye stripe stripe mouth face ear person ear mouth face nose nose', 'objects_no_rep': 'stripe head person zebra ear nose eye face mouth mane', 'caption': 'a pencil drawing of a zebra and her baby .'}
# 50
# {'objects': 'airplane book engine wing tail letter letter letter letter letter letter', 'objects_no_rep': 'tail engine airplane letter book wing', 'caption': 'airline -- reasons why person leads the way in experience'}
# 51
# {'objects': 'boat boat boat boat water tree pillow table cloud building umbrella tree column pillar boat water tree sky tree boat chair plant window couch building boat arm plant chair wall chair boat coffee table sofa couch boat column planter sofa boat boat table tree couch window chair dock cushion tree cloud building wall pool pot chair cushion boat water', 'objects_no_rep': 'pot pillow planter wall pillar column pool coffee table plant window sofa chair couch arm building sky dock cloud boat water umbrella tree table cushion', 'caption': 'ninety per cent of the units have balconies with views .'}
# 52
# {'objects': 'flag flag flag flag stick flag jacket flag pole flag hair hair girl pole person umbrella crowd letter pole man flag person stand sign person child coat flag person hair person flag letter person pole pole flag ear person', 'objects_no_rep': 'umbrella flag coat jacket person man girl ear sign child letter pole crowd hair stick stand', 'caption': 'a demonstration of a group of people practicing their rights'}
# 53
# {'objects': 'tie man hair hair hair dress arm girl suit hair girl hair dress woman dress woman bracelet hand building hand girl person shirt eye person face face head man person arm girl hand head face child hand person woman person', 'objects_no_rep': 'building shirt head man person bracelet girl hand child tie suit eye face woman hair arm dress', 'caption': 'actor and daughters uk premiere held'}
# 54
# {'objects': 'bird wall wall book curtain plate sky name wall tree', 'objects_no_rep': 'tree name sky plate wall curtain book bird', 'caption': 'a fine , grainy vector pattern in black and white .'}
# 55
# {'objects': 'flower flower flower flower flower flower rose flower flower rose leaf flower flower flower leaf flower flower petal rose flower flower wall flower background flower leaf ball flower flower flower rose leaf petal flower leaf background rose', 'objects_no_rep': 'leaf flower petal background ball wall rose', 'caption': 'seamless border of orange roses and paisley , pattern on a white background .'}
# 56
# {'objects': 'shirt glasses glasses boy girl boy boy boy person girl boy boy girl man shirt hair boy shirt girl shirt man person shirt boy boy backpack man necklace hair hair head boy shirt hand man column face shirt head man dress person person person boy child hat person vest person face girl man person girl column person child', 'objects_no_rep': 'column boy shirt head person man hand girl glasses hat child face vest hair necklace backpack dress', 'caption': 'students in front of a school'}
# 57
# {'objects': 'bench tree building tree sky shadow porch window wall window lawn tree shadow building grass wall light sidewalk', 'objects_no_rep': 'tree building shadow porch bench grass sidewalk window sky lawn wall light', 'caption': "museum , opened is among the 20th - century 's most significant buildings ."}
# 58
# {'objects': 'sky bus mountain tree water sky road shore boat water tree ground line background roof shore field road grass road beach grass building river field land building building car car', 'objects_no_rep': 'beach tree field building water river mountain roof land car background grass shore sky line ground road boat bus', 'caption': 'river as it meets bodies of water where airline meets'}
# 59
# {'objects': 'guitar jean man hair hand shoe jacket microphone leg hand shirt shoe leg arm face light stand sneaker light speaker wheel sky eye light shoelace mouth nose collar head', 'objects_no_rep': 'man shoelace mouth jean guitar jacket shirt wheel face shoe arm hand nose stand sky light sneaker speaker head eye collar hair leg microphone', 'caption': 'young rock star jamming on a guitar'}
# 60
# {'objects': 'boat water water rock rock buoy flower flower boat string string rock tree boat pole rock rock rock line engine ball string plant flower', 'objects_no_rep': 'buoy string flower tree engine plant pole ball line rock boat water', 'caption': 'a moored fishing boat viewed from island .'}
# 61
# {'objects': 'face nose tiger hair mouth eye eye tiger mouth poster ear eyebrow mouth eye eyebrow bear person lion head', 'objects_no_rep': 'tiger head poster person ear nose eye face eyebrow mouth hair lion bear', 'caption': 'vector illustration of person isolated on a white background'}
# 62
# {'objects': 'car sky line curb tree pole road car vehicle line grass car road light headlight car car wheel car line light wheel car car vehicle street car line headlight truck tire person vehicle', 'objects_no_rep': 'street curb tree tire wheel headlight person car truck pole grass line sky vehicle road light', 'caption': 'emergency services were called after a car smashed through a set of traffic lights'}
# 63
# {'objects': 'sheep fence face sheep tree leg snow tree rope fence snow sheep rock snow rope leg leg snow gate post tree head snow post ground fence tree snow snow wood tree tree', 'objects_no_rep': 'tree wood snow head sheep post fence face gate ground rock rope leg', 'caption': 'sheep with a black face fenced in on a winter day'}
# 64
# {'objects': 'flag pole tree tree bench fountain sky tree kite flag flag flower flag tree flag tree flag flag flag flag building hedge american flag bush american flag park tree tree american flag american flag sidewalk trunk steeple flag building cloud flag flag american flag grass flag tree trunk flower trunk banner american flag flag road', 'objects_no_rep': 'hedge bench pole banner flag flower american flag kite sidewalk steeple road fountain building tree trunk sky bush cloud tree trunk grass park', 'caption': 'a small park with flags and a yellow banner around a tree in support of troops'}
# 65
# {'objects': 'drink rim water table glass ice line drink mouth letter', 'objects_no_rep': 'ice drink table letter line mouth rim glass water', 'caption': 'isolated water glass on a white background'}
# 66
# {'objects': 'window house porch window window bench window window porch column poster building porch window wall porch flower column light column table building wall base flower wall window building step flower window clock window window window stand house wall chair flower grass window', 'objects_no_rep': 'column building clock flower poster base porch bench table step grass window stand chair wall house light', 'caption': "when choosing your new outdoor color palette , opt for something that will enhance your home 's architectural style and give you plenty of curb appeal ."}
# 67
# {'objects': 'chair chair curtain bottle wall curtain ceiling chair chair chair table screen speaker menu woman table chair chair speaker plate room light wall table chair woman wall door chair curtain picture woman light flower picture woman woman menu person curtain man picture person dress chair woman room woman hair person jacket plate candle chair light wall person chair floor lamp light table book chair screen candle plate table shirt lamp lamp table girl person light stool ceiling building menu person light light wall napkin napkin light chair countertop light light person table person', 'objects_no_rep': 'menu man wall book woman flower jacket lamp shirt candle chair floor ceiling building room person girl screen bottle plate countertop door light dress speaker stool table napkin hair curtain picture', 'caption': 'person at a corporate event'}
# 68
# {'objects': 'tractor sky mountain shadow tire mountain cab mirror window tire mountain window front grass mountain ground mountain mirror wheel grill mountain grass wheel field door man dirt metal', 'objects_no_rep': 'tire field wheel front grill man shadow cab mountain dirt grass ground door window sky mirror metal tractor', 'caption': 'bulldozer on a building site'}
# 69
# {'objects': 'shirt man jacket sky man tree short short man man tree man jacket shirt shoe tree tree sock belt pant shoe shirt man man hat tree shoe shoe shoe field tree tree tree shoe shoe belt pant shoe shoe short pant shoe tree person hair shoe shoe grass person head pant hair person jacket head shadow shoe shoe person jacket head hair hair head sock shirt person', 'objects_no_rep': 'pant tree field belt jacket shirt head man person shadow hat grass sky hair shoe short sock', 'caption': 'person finishes at the top'}
# 70
# {'objects': 'cloud tree water tree tree leaf leaf fish leaf tree', 'objects_no_rep': 'leaf tree fish cloud water', 'caption': 'country shape animated on the satellite map of the globe'}
# 71
# {'objects': 'tree tree sign tree tree person tree ground person wood tree tree tree bus tree sky tree arrow road tree logo trunk arrow sign sign trunk', 'objects_no_rep': 'tree wood trunk arrow person sign logo sky ground road bus', 'caption': 'paths are clearly marked with signs like this .'}
# 72
# {'objects': 'ear leg woman shirt head hand arm shoe ball glove short shoe skirt shadow hat logo shoelace leg hair logo hand face ground visor cap mouth hat nose shadow girl head knee person', 'objects_no_rep': 'knee shadow logo shoelace mouth visor short glove woman shirt skirt ball face ground shoe arm person hand girl ear nose cap head hat hair leg', 'caption': 'putts for birdie on the second hole during the final round of the golf tournament .'}
# 73
# {'objects': 'tree sky tree water branch horizon tree bush bush dirt field sky leaf', 'objects_no_rep': 'leaf tree field branch horizon dirt sky bush water', 'caption': 'person shot from a cliff looking out at the lake and horizon .'}
# 74
# {'objects': 'heart heart dress hand woman arm shadow head hand hand frame word hair hat cord hand', 'objects_no_rep': 'head hand shadow heart frame hat cord hair word dress arm woman', 'caption': "sending this angel your way ... it lights the way with it 's tiny candle ."}
# 75
# {'objects': 'glove hair woman short sandal tree paper sky leg jacket sandal tree fence leg purse woman heel coat head ground face girl tree shirt ground heel beach tree foot hand road', 'objects_no_rep': 'sandal short glove woman jacket shirt heel face ground road purse beach coat foot girl hand sky tree head fence hair leg paper', 'caption': 'i love the colours of her clothes .'}
# 76
# {'objects': 'poster animal envelope tree tree tiger arm word poster word', 'objects_no_rep': 'tree tiger poster envelope word arm animal', 'caption': 'a very simplified location and geological map of the area and adjacent coast'}
# 77
# {'objects': 'car floor wall window windshield letter sign reflection reflection reflection hood tire license plate mirror chair plate wheel tire window chair shadow light wheel mirror wall handle', 'objects_no_rep': 'floor tire windshield wheel shadow license plate car sign handle letter window reflection chair wall hood plate mirror light', 'caption': 'ask owner for photos of the car'}
# 78
# {'objects': 'tree tree envelope tree tree tree tree tree tree tree tree arrow sign pole tree sign tree circle tree tree drawing christmas tree sign triangle', 'objects_no_rep': 'drawing tree arrow sign christmas tree circle pole triangle envelope', 'caption': "the state of the world 's forests"}
# 79
# {'objects': 'pant tree building person person shadow tree pole person ski jacket pole ski snow shadow tree tree ski suit building tree tree person building person person tree shadow sky snow tree mountain snow tree building ski pole ground snow person shadow hill pole', 'objects_no_rep': 'pant tree building snow jacket person shadow mountain ski suit pole hill sky ground', 'caption': 'the mountain slopes covered with powdery snow are popular with visitors , especially foreign tourists'}
# 80
# {'objects': 'tree tree tree sky tree tree tree tree tree stick tree bird stick tractor tree tree truck field stick tire ground tractor dirt bird sky vehicle tire window', 'objects_no_rep': 'tree field tire truck dirt window stick sky ground vehicle bird tractor', 'caption': 'farm tractor is moving on the field , cultivating land'}
# 81
# {'objects': 'dog nose ear grass string head leg paw shoe mouth pant grass leg eye person man leg person object grass face flower writing letter tongue watermark foot letter', 'objects_no_rep': 'man mouth object pant dog flower letter face tongue shoe writing person foot ear nose watermark paw string head eye grass leg', 'caption': 'master playing with his little golden retriever dog on the lawn'}
# 82
# {'objects': 'window pot plant plant wall ground tree flower pot house flower flower christmas tree leaf flower window flower leaf leaf flower bush', 'objects_no_rep': 'leaf tree flower pot christmas tree plant ground window bush wall house', 'caption': 'year later the small shrubs doubled in size .'}
# 83
# {'objects': 'jacket hand person woman bat wallet phone case arm pant', 'objects_no_rep': 'pant bat jacket person hand case phone wallet arm woman', 'caption': 'according to the model , she regularly gets told it looks'}
# 84
# {'objects': 'hand man hair watch cupcake shirt belt eye necklace sleeve hand dress woman face door hand hair couple ring nose face ring wall button light eye shirt eye forehead head nose mouth finger ear mouth picture head window wall whipped cream eye dress necklace', 'objects_no_rep': 'belt man finger mouth wall woman shirt cupcake whipped cream face watch window necklace forehead hand ear nose couple ring door light dress head sleeve button eye hair picture', 'caption': 'person and the fiancee at their engagement party .'}
# 85
# {'objects': 'dog eye nose ear eye eye dog face wall whisker body head word wall eye leg mouth chin muzzle letter shirt chin whisker neck', 'objects_no_rep': 'chin dog body shirt whisker head word ear nose eye leg face muzzle letter mouth neck wall', 'caption': 'good night id been working like a dog i should be sleeping like a log'}
# 86
# {'objects': 'umbrella sky sky man tree water tree boat boat shirt cloud hut cloud boat tree person boat boat cloud pant person sign person car cloud boat tree cloud tree tree tree person hat cloud boat hut person building sign grass tree beach tree person car cloud person tree person roof cloud tree child person person beach boat cloud boat sky car water dirt water cloud vehicle', 'objects_no_rep': 'man vehicle pant shirt car roof beach building hut person sign dirt sky cloud boat water umbrella tree hat child grass', 'caption': 'the water was never deeper than your chest .'}
# 87
# {'objects': 'building building window sky chair tower umbrella clock window window person table window window umbrella window light table person window window light window window chair wall window window table window window window doorway table chair sky letter light door chair fountain window light water line window wall letter window doorway door window window chair window archway street', 'objects_no_rep': 'street umbrella building clock fountain water person table letter doorway window sky line chair wall tower archway door light', 'caption': 'twilight over italian gothic structure and the medieval town'}
# 88
# {'objects': 'cake flower flower table wall flower flower flower flower flower flower flower sunflower card sunflower flower flower flower drawer leaf flower paper flower leaf flower leaf flower flower flower base flower block leaf flower frosting sunflower leaf vase leaf knob flower frosting flower base bouquet figurine', 'objects_no_rep': 'leaf flower drawer base knob table block cake bouquet frosting sunflower figurine wall vase card paper', 'caption': 'a simple wedding cake with lego bride and groom topper and cake pops .'}
# 89
# {'objects': 'pot plant floor light towel cabinet window floor plant hanger frame wall door plant man table ceiling towel cabinet door television door stool cabinet picture cabinet door wall person closet picture frame picture fireplace door word door', 'objects_no_rep': 'towel pot man hanger picture frame wall fireplace plant window floor ceiling person television closet door light stool frame table word picture cabinet', 'caption': 'simple custom leather pulls for your dresser , cabinets , or doors .'}
# 90
# {'objects': 'tree tree tree grass log tree sky grass tree tree trunk tree tree tree field trunk leaf trunk tree wood park tree trunk tree wood', 'objects_no_rep': 'leaf tree log field wood trunk grass sky park', 'caption': 'sunny woodland morning along river .'}
# 91
# {'objects': 'poster tiger eye eye animal face horse mouth horse person person person', 'objects_no_rep': 'horse tiger poster person eye face mouth animal', 'caption': 'person , why u turn me on with your designs ? i believe i will bepinning some more of his work here in a bit .'}
# 92
# {'objects': 'microphone hair leg woman hand face person leg nose shirt eye hand person stage woman person hand eye ear leg boot head foot hand hand dress arm face necklace mouth man cell phone costume leg boy hand strap person woman mouth head', 'objects_no_rep': 'man mouth woman boy shirt face stage necklace arm person hand foot ear nose costume dress head eye cell phone hair leg boot strap microphone', 'caption': 'pop artist performs on stage .'}
# 93
# {'objects': 'smoke cloud water sky bridge building water dock building cloud dock cloud building building building pole building reflection reflection light building tower reflection tower building dock building post light cloud light bridge boat boat smoke reflection parking lot cloud cloud reflection boardwalk light beam', 'objects_no_rep': 'building post beam pole boardwalk smoke sky bridge dock reflection parking lot tower cloud boat water light', 'caption': 'industrial plants in the distance at night'}
# 94
# {'objects': 'sky city building tower water tower tower building cloud top city building building cloud line cloud line string river letter building light sign line', 'objects_no_rep': 'building string river sign letter top city sky line tower cloud water light', 'caption': 'building and skyscraper light up at night'}
# 95
# {'objects': 'hand man hair eye eye wrist shirt beard mouth nose eyebrow ear eyebrow ear finger face chain bracelet mustache head eye arm design finger design neck lip arm logo finger', 'objects_no_rep': 'man finger eyebrow mouth wrist chain neck logo shirt face beard arm lip hand bracelet ear nose mustache head design eye hair', 'caption': 'actor is an actor who started out as a lawyer .'}
# 96
# {'objects': 'pillow wall pillow pillow tray lamp lamp table cushion couch table picture table door floor window wall picture cushion sofa picture coffee table rug picture carpet shade shade picture picture picture frame picture building picture area rug couch picture frame woman frame picture wood picture picture picture', 'objects_no_rep': 'pillow wall woman area rug carpet wood lamp coffee table shade window sofa couch floor building door rug frame table picture tray cushion', 'caption': 'color good with green couch in living room ... favorite ... i think maybe a little too peach ?'}
# 98
# {'objects': 'tree sky cloud cloud tree cloud sky tree cloud cloud cloud tree bird bird cloud', 'objects_no_rep': 'tree cloud bird sky', 'caption': 'tree branches swing at real time with the wind while clouds move fast in time lapse'}
# 99
# {'objects': 'plate cake plate tile tile table cup fork saucer coffee coffee ground plate cup tile liquid knife tile utensil base glass dessert saucer', 'objects_no_rep': 'dessert liquid utensil tile base cup coffee table cake saucer ground plate knife fork glass', 'caption': 'my coffee of the day !'}
# 100
# {'objects': 'cat ear head paw leg pillow eye face couch cushion toy face nose cushion paw head leg fur nose leg floor paw pillow', 'objects_no_rep': 'floor head cushion fur pillow ear nose eye cat face leg paw toy couch', 'caption': 'mirror image : lonely kitten seeks comfort in the form of a cuddly cat'}
# 101
# {'objects': 'corn corn chair table corn tray wall man shirt hand arm hand letter arm table person corn corn shirt bowl countertop person ring', 'objects_no_rep': 'shirt man person hand corn table letter bowl ring countertop chair wall tray arm', 'caption': 'this trick really is the best way to cut corn off the cob , because it saves making a big mess on the counter and floor .'}
# 102
# {'objects': 'toothbrush hair girl toothbrush hand girl hair wall shower glove hand hand jacket eye face face nose shower mirror head sink coat tub eye bathtub wall toothbrush mouth wall tap shower handle girl head wall head toothbrush teeth tile necklace', 'objects_no_rep': 'bathtub tile handle shower mouth wall mirror glove tap jacket face necklace coat hand girl nose tub head sink eye toothbrush teeth hair', 'caption': 'portrait of young mother and little child brushing their teeth together while standing in the bathroom'}
# 103
# {'objects': 'boat boat boat water sky boat building cloud building sky boat roof boat house building sailboat mast mast boat sail boat window harbor person mast flag building pole house cloud building building cloud house cloud mast building pole mast boat house roof building boat mast pole house water mast boat light', 'objects_no_rep': 'building flag house sail mast person harbor roof pole sailboat window sky cloud boat water light', 'caption': 'the harbor a small village'}
# 104
# {'objects': 'building sign sign tree balcony sky bolt tree bolt figure man tree tree person leaf triangle balcony window railing screw fire escape', 'objects_no_rep': 'bolt leaf building tree screw man person railing sign triangle window sky fire escape figure balcony', 'caption': 'a traffic sign warns of surfers crossing !'}
# 105
# {'objects': 'flower flower flower flower flower flower flower flower flower flower flower flower flower flower towel flower flower flower flower writing envelope', 'objects_no_rep': 'writing towel envelope flower', 'caption': 'greeting card with bright blue text and abstract christmas tree on a white background vector art illustration'}
# 106
# {'objects': 'envelope envelope paper flower rose paper flower letter flower flower flower table word flower paper flower', 'objects_no_rep': 'flower table letter envelope word paper rose', 'caption': 'such pretty watercolor flowers and can be in any languages'}
# 107
# {'objects': 'book kite writing paper leg paper picture umbrella photo leg letter writing writing ground handle panel page tile', 'objects_no_rep': 'writing umbrella page tile photo kite handle letter ground panel leg picture book paper', 'caption': 'newspaper became a free newspaper'}
# 108
# {'objects': 'grass grass field grass grass field grass grass letter grass', 'objects_no_rep': 'letter grass field', 'caption': 'ancient open prairie of west on a cold morning beds and grasses cover much of the area'}
# 109
# {'objects': 'tree tree tree tree tree wood tree tree branch tree tree tree sky tree', 'objects_no_rep': 'tree wood branch sky', 'caption': 'forest on a sunny day'}
# 110
# {'objects': 'dog man jean belt shirt grass jean hair collar tree woman grass ear sky shirt hair hand grass tree pole ear glasses girl fence hand hand head pole mountain tree bush tree tshirt couple tree bush suspender face smile strap ski poles strap head head leg person', 'objects_no_rep': 'belt man ski poles glasses pole jean woman dog shirt mountain face person hand girl ear suspender sky bush couple smile tree tshirt head fence grass collar hair leg strap', 'caption': 'happy senior couple with dog on a hike in summer in the nature'}
# 111
# {'objects': 'poster castle paper paper building word bird paper airplane bottle building word column', 'objects_no_rep': 'column building poster airplane castle bottle word bird paper', 'caption': 'illustrator who has a rather simply haunting style .'}
# 112
# {'objects': 'branch branch roof branch branch snow tree snow wood branch snow', 'objects_no_rep': 'tree wood branch snow roof', 'caption': 'birds fly up to the feeder and take seeds , snow on trees , falling snowflakes for the birdhouse'}
# 113
# {'objects': 'glasses glasses light hair man man shirt woman hair hair hat man hair shirt light man hair hand light hat light wall woman head head face girl light hand hand person shirt ceiling nose person jacket woman shirt person face woman room person head boy nose hand hand woman', 'objects_no_rep': 'ceiling room boy shirt head jacket man person hand hat glasses girl nose face woman hair wall light', 'caption': 'hands in \\ walking through his old elementary hallways , person is congratulated by current students .'}
# 114
# {'objects': 'head leg grass bush grass tail tail grass tail head neck ear leg giraffe tail field head dog grass head animal', 'objects_no_rep': 'tail field dog head ear grass giraffe neck bush leg animal', 'caption': 'leopard dragging its kill in the desert'}
# 115
# {'objects': 'sign window sign stroller clock bag ceiling wall person sign person mannequin man building person person jacket person wall fan mannequin jean pole person shirt store floor person person person jacket person sign person light pole person pole pole person light pole post globe ornament post sign pole person post light railing person woman jacket person jean jacket pant pant woman man jacket jean roof sidewalk coat post woman railing pole', 'objects_no_rep': 'clock man pole jean wall woman pant jacket shirt ornament globe roof bag sidewalk window fan stroller mannequin floor ceiling building coat person store railing sign light post', 'caption': "on a lovely winter 's evening ."}
# 116
# {'objects': 'text text text text writing word poster word text word', 'objects_no_rep': 'word writing text poster', 'caption': "first screenshot of the conversation between users , where one abruptly finds out that they 've been reading a version of harry potter ."}
# 117
# {'objects': 'tree car man sky pant man jean hair hair pant tree shirt hair car car tree woman car woman suit line truck car jacket road head jacket street belt suit hat person street car building line leg street car shoe coat road face vehicle person street crosswalk shoe sidewalk jacket uniform building helmet street light pant person tree head person shoe', 'objects_no_rep': 'belt man jean vehicle woman pant street street light shirt jacket car sidewalk face shoe road helmet building coat person suit uniform line sky crosswalk tree head hat truck hair leg', 'caption': 'taking to the streets : person is psychedelic rock artist in this mock up of their album cover'}
# 119
# {'objects': 'glass table tea rim background wall reflection liquid base glass bottom', 'objects_no_rep': 'liquid base bottom table background reflection tea wall rim glass', 'caption': 'glass of whiskey with ice on the table'}
# 120
# {'objects': 'poster house window skyscraper building circle toy box window poster text diamond', 'objects_no_rep': 'building poster box diamond circle text window skyscraper toy house', 'caption': 'vector illustration of a flat design of the house'}
# 121
# {'objects': 'tree building car car window sign window door window bench sidewalk building sign tree trunk bike window window car ground bar bicycle arrow window street bike wheel doorway tree sign chain window tree light window door letter barrier building window letter window tree trunk bicycle', 'objects_no_rep': 'bench chain bike street bar wheel arrow bicycle car sidewalk letter window barrier ground building sign tree trunk door light tree trunk doorway', 'caption': 'police car approaching a building by night'}
# 122
# {'objects': 'camera table strap zipper strap logo table belt logo camera', 'objects_no_rep': 'belt camera table logo zipper strap', 'caption': 'the best gift for photographers - wrist strap - black / blue - lucky camera straps - genuine leather camera strap personalised handmade'}
# 123
# {'objects': 'light light light light handle lamp neck background room shadow', 'objects_no_rep': 'room lamp shadow handle background neck light', 'caption': 'blue and pink wavy shiny ribbon on a dark background vector'}
# 124
# {'objects': 'sock man sky hair arm shirt ear hand face water shoe railing head pant hoodie hair arm pole cloud light beard cloud pole zipper rail ground jean sneaker lamp hand lamp trash can track water cloud nose leg', 'objects_no_rep': 'track man pole jean zipper pant lamp shirt face beard shoe ground arm hand hoodie ear railing nose sky cloud water light rail sneaker head trash can hair leg sock', 'caption': 'fit man stretching and listening to music by the sea'}
# 125
# {'objects': 'tree bull tail grass tree tree tree tree tree tree tree wood bull tree field animal branch branch forest grass head tree tree trunk tree trunk cow flower', 'objects_no_rep': 'tail tree wood field branch head bull forest trunk flower tree trunk grass cow animal', 'caption': 'biological species scratching an itch against a tree'}
# 126
# {'objects': 'chimney window plant window window roof tree flower pot light building stone tree roof window house wall window flower roof window wall light wall roof plant flower pot building sky tree flower flower light', 'objects_no_rep': 'tree chimney flower building pot stone roof plant window sky wall house light', 'caption': 'a slideshow of some of the best tiny houses available'}
# 127
# {'objects': 'table plate flag stick bowl number pie word food stripe writing word surface', 'objects_no_rep': 'writing flag stripe surface table food stick plate bowl word pie number', 'caption': 'flag and festive cake on a plate'}
# 128
# {'objects': 'clock clock chair flower vehicle face vehicle flower flower car chair flower', 'objects_no_rep': 'clock flower car face chair vehicle', 'caption': 'could make the hallway to the master suite all glass to add some additional separation interesting !'}
# 129
# {'objects': 'dress woman dress head hair face dress sculpture wall arm', 'objects_no_rep': 'head sculpture face hair wall dress arm woman', 'caption': 'wedding dress with a v neck'}
# 130
# {'objects': 'dress dress dress dress dress hair dress necklace tree woman woman woman woman head flower dress chair woman wall dress dress woman chain chain woman flower earring wall flower tree hand woman flower brick flower goat hair band hair tree dress hair arm bench fence tree wall brick wall face park girl sky hair flower dress hair ponytail person person pole woman eye bench', 'objects_no_rep': 'band brick bench pole chain wall woman flower ponytail face chair brick wall necklace arm person hand girl goat sky dress tree head fence eye earring hair park', 'caption': 'bride at the barn at high point farms'}
# 131
# {'objects': 'man tie man man man suit hand tie face uniform hair suit mouth hand hair hand man hair face number man shirt jacket shirt jersey nose screen suit hat head hair nose cuff person person head ear', 'objects_no_rep': 'shirt jacket head man cuff hand hat person nose screen suit tie face ear uniform mouth hair jersey number', 'caption': 'coach and person react against basketball team during event .'}
# 132
# ...
# 6873
# {'objects': 'pillow pillow pillow bed dress hair girl girl head foot hand hair pillow nose glasses headband tie dresser ring foot flower foot dress flower shirt face man hand hair blanket pole leg mouth hand boy vase arm chin skirt wall pillow girl flower hand collar', 'objects_no_rep': 'man pillow glasses pole mouth wall headband boy flower shirt blanket skirt face vase arm foot girl hand nose ring dresser dress chin head bed tie collar hair leg', 'caption': 'groom adjusting his tie with girls in the background'}
# 6874
# {'objects': 'man bench hat tie pant tree hand tree tie face grass head bush bush jacket leg sky grass suit grass shirt shirt strap park arm back writing tree brim tie strap leg', 'objects_no_rep': 'man brim bench pant jacket shirt face arm writing hand suit bush sky tree head hat back tie grass leg park strap', 'caption': 'senior man sitting on a wooden bench and looking at camera , in a park'}
# 6875
# {'objects': 'helmet glove face arm player arm logo hand jersey finger logo man man pant tattoo stripe shirt uniform finger player logo hand wristband logo person band', 'objects_no_rep': 'pant stripe player shirt band man tattoo hand person face finger jersey logo uniform wristband helmet glove arm', 'caption': 'person reacts during the second quarter against american football team .'}
# 6877
# {'objects': 'eye ear man hair head wall nose ear hat eyebrow collar eye shirt watch face mouth eyebrow jacket logo letter pocket chin logo arm word cap shirt tie neck', 'objects_no_rep': 'pocket man eyebrow mouth logo neck wall shirt jacket letter face watch arm ear nose cap chin head hat eye tie collar hair word', 'caption': 'actor with arms folded looking to his left in a scene from the film'}
# 6878
# {'objects': 'leaf water leaf leaf leaf leaf leaf water leaf ground leaf leaf leaf grass leaf leaf ripple leaf leaf rock animal sand bank', 'objects_no_rep': 'leaf sand bank grass rock ripple ground water animal', 'caption': 'crocodile is sleeping near the water'}
# 6879
# {'objects': 'sky bird kite bird sky flower bird string flower flower', 'objects_no_rep': 'string flower kite sky bird', 'caption': 'illustration of a many little messy music notes'}
# 6880
# {'objects': 'tree wall tree sky tree tree grass tree bush trunk sky tree trunk tree bush archway sky flower yard sign', 'objects_no_rep': 'tree flower trunk sign yard grass sky bush wall archway', 'caption': 'our gate into the garden'}
# 6881
# {'objects': 'face sculpture tree nose tree leaf flower head grass tree stone leaf ear', 'objects_no_rep': 'leaf tree flower stone head ear nose sculpture face grass', 'caption': 'with all of her statues , she paid close attention to how the sculpture would be viewed from all angles .'}
# 6882
# {'objects': 'sidewalk car building car truck tree truck sign sign tree license plate car car window license plate road van car tire sign tire car light sky tree tire light truck light street truck tail light plate tree parking lot car traffic tail light truck light', 'objects_no_rep': 'street building tree tire tail light license plate truck car sign sidewalk van traffic window sky plate parking lot road light', 'caption': 'the traffic earlier today was caused by the closure'}
# 6883
# {'objects': 'dress chair watch dress paper bag hair chair woman woman glasses floor shoe sign shirt hand shoe man curtain chair man leg hair purse skirt ceiling arm chair light head shirt hand tag hand shirt face', 'objects_no_rep': 'man glasses woman shirt skirt bag face watch chair shoe purse arm floor ceiling hand sign light dress head tag hair leg curtain paper', 'caption': 'celebrity attends the fashion show during spring .'}
# 6884
# {'objects': 'fan building window wall ceiling wall chimney machine board floor box ladder vent wall machine wall building box lamp column room bottle window', 'objects_no_rep': 'floor ceiling building chimney lamp column room ladder machine box board window bottle fan wall vent', 'caption': 'the entire room is finished with wainscoting .'}
# 6885
# {'objects': 'boat hair sky water face boat water boat short foot cloud canopy person shirt boy nose head person girl leg boat wave motor water cloud wave life vest wave shirt cloud child hand', 'objects_no_rep': 'short boy shirt face life vest motor canopy person foot girl hand nose sky cloud boat water head wave child hair leg', 'caption': 'calm bay side of the island'}
# 6886
# {'objects': 'bird beak head field bird boat wall banner wing letter pole pole pole sign letter stick person boat wall line triangle word leg', 'objects_no_rep': 'banner field head person word sign letter pole triangle leg line stick beak wall bird boat wing', 'caption': 'fish - 40cm square acrylic painting of a cutter .'}
# 6888
# {'objects': 'boat roof window window window sky cloud grass house window building door building window water water building wall hill building rock door window mountain shutter building hillside window river cloud tree window weed rock field board cloud', 'objects_no_rep': 'rock wall house field mountain roof window hillside building river board sky cloud boat water door shutter tree grass hill weed', 'caption': 'a facade of gates and sliding panels seals the house up in rough weather or opens it up when the sun is out .'}
# 6889
# {'objects': 'dog water sky cloud water water tree mountain snow eye neck head toy mountain nose sky mouth water rock branch face rock dog tree eye mountain mouth tree tree', 'objects_no_rep': 'tree dog snow branch head mountain nose eye face neck sky mouth rock toy cloud water', 'caption': 'working animal in fron mountain range'}
# 6890
# {'objects': 'glove shoe man shoe pant man shoe ball pole face shirt hat helmet shoe shirt hat grass pole baseball person field glove glove line sock jersey helmet grass uniform vest shadow', 'objects_no_rep': 'pant helmet field shirt man person shadow hat ball pole face grass line baseball jersey uniform shoe vest glove sock', 'caption': 'cricket player hits out while politician looks on during the tour match .'}
# 6891
# {'objects': 'tree tree sky tree wall bird tree building branch tree tree tree antenna', 'objects_no_rep': 'building tree branch sky antenna wall bird', 'caption': "the sun setting at the back of our front neighbour 's house ."}
# 6892
# {'objects': 'building sky snow rock snow tower snow window flag window rock door spire rock snow tower person rock snow spire person flag snow castle ground sky window person person mountain photo spire spire archway picture spire', 'objects_no_rep': 'building flag snow picture person mountain photo castle window sky rock spire ground tower archway door', 'caption': 'how to draw a castle : step by step'}
# 6893
# {'objects': 'ear hair shirt hair eye hand hand eyebrow boy ear shirt man hair eye string man wall arm head curtain person face nose eyebrow window neck neck person writing', 'objects_no_rep': 'writing string boy shirt head man person hand ear nose eye face eyebrow window hair neck wall curtain arm', 'caption': 'teenage boy getting ready for school in the morning'}
# 6894
# {'objects': 'ceiling chair floor chair plant chair ottoman plant building chair plant couch plant table rug plant plant countertop wall planter table table ottoman chair chair stool monitor floor coffee table plant column monitor column planter ottoman plant coffee table vent chair countertop light flower table table sofa', 'objects_no_rep': 'floor ceiling building column flower stool rug coffee table planter plant table monitor countertop chair wall sofa vent ottoman couch light', 'caption': 'bar & lobby by quality'}
# 6895
# {'objects': 'head bird eye feather bird feather feather wall whisker flower grass feather', 'objects_no_rep': 'flower head whisker eye grass feather wall bird', 'caption': 'bird : upper part and head from turkey with white feathers and back lit by the sun'}
# 6896
# {'objects': 'animal ground stick animal stick leaf blade stick grass stick branch', 'objects_no_rep': 'leaf branch grass blade stick ground animal', 'caption': 'a close up of biological species'}
# 6897
# {'objects': 'dress hair person woman writing wall head hair belt dress face woman bag word woman arm sleeve', 'objects_no_rep': 'writing belt head person word sleeve bag face hair wall dress arm woman', 'caption': 'to the girl in the mirror ~ # quotes'}
# 6898
# {'objects': 'tractor sky grass cloud tire truck tree water cloud wheel tire mirror light trailer field windshield tire window wheel pipe wheel cart grass cloud door wheel wheel sky tractor wheel trailer pipe cloud cloud field trailer tree pipe tree truck window', 'objects_no_rep': 'tree tire field water wheel windshield pipe cart truck grass door trailer sky window mirror cloud tractor light', 'caption': 'combine harvester and tractor in a grain field'}
# 6899
# {'objects': 'pillow wall pillow bed headboard wall ceiling lamp window window light nightstand pillow picture window picture floor outlet skylight footboard room leg frame bed table light blanket frame lamp sheet', 'objects_no_rep': 'floor ceiling footboard room lamp picture outlet blanket pillow skylight frame bed headboard leg table window wall sheet nightstand light', 'caption': 'king size bed with an ocean view .'}
# 6900
# {'objects': 'tree sign flower grass wall tree sign flower wire date', 'objects_no_rep': 'tree flower sign grass date wire wall', 'caption': 'island , showing the main areas of activity'}
# 6901
# {'objects': 'line wall tire floor ceiling window door tire coat cord bag light ceiling sign bus window light door bar beam cable window rack cord wall shelf wheel cord fire truck pole hose glass stand truck wire building', 'objects_no_rep': 'pole wall glass bar wheel bag beam window floor ceiling fire truck tire coat building sign shelf cord line stand wire bus door light truck cable rack hose', 'caption': 'fire trucks at the airport'}
# 6902
# {'objects': 'icon envelope tree mountain tree tree icon icon icon tree tree', 'objects_no_rep': 'icon tree envelope mountain', 'caption': 'this map shows how the world has been hurt by climate change so far'}
# 6903
# {'objects': 'collar eye tail collar eye cat grass leash ear leaf leg paw tree face tree cat ground nose ground', 'objects_no_rep': 'leaf tail tree ear paw nose eye cat grass face ground collar leg leash', 'caption': 'person the red cat walking outside with tail up'}
# 6904
# {'objects': 'man jersey nose tattoo ear mouth hair arm number eye stripe head sleeve face letter stripe person shirt wall logo', 'objects_no_rep': 'stripe shirt head man tattoo sleeve person ear nose eye letter face jersey mouth hair logo wall arm number', 'caption': 'soccer player attends a training session after a public team presentation in the stadium .'}
# 6905
# {'objects': 'sky cloud cloud cloud water cloud cloud tree tower tree bush tree tree cloud building cloud cloud bush tree bush bush tree tree tree lighthouse reflection light sky letter reflection cloud picture dock cloud sunset', 'objects_no_rep': 'tree building picture letter sunset sky bush lighthouse reflection dock tower cloud water light', 'caption': 'museum at sunset along the lagoon'}
# 6906
# {'objects': 'tail sky airplane door cloud engine wing wing door door logo cloud door cockpit logo window stabilizer sky window fuselage window window', 'objects_no_rep': 'tail engine wing fuselage cockpit airplane logo sky window stabilizer cloud door', 'caption': 'this computer graphic image shows aircraft line in colors'}
# 6907
# {'objects': 'poster glass wine hand house hand tree person window tree wine glass arm vase window table person tree base tree window flower sleeve tree finger roof window tree window finger wall castle field table tree building finger', 'objects_no_rep': 'tree field flower building poster person hand base sleeve roof table arm finger wine window castle wall house vase glass', 'caption': "here are easy tricks to picking out a glass -- or bottle -- of wine at a restaurant you 'll enjoy every time ."}
# 6908
# {'objects': 'boot jean tile boot person shoe knob lid ground knob top pole knob tile tile street pole top pillar leg', 'objects_no_rep': 'street pillar person tile knob leg top lid pole jean ground shoe boot', 'caption': 'video game subject is one of the popular local custom'}
# 6909
# {'objects': 'flower flower flower flower flower cake flower flower table flower flower bird eye dragon feather ball flower border flower flower ball leaf ball cake flower', 'objects_no_rep': 'leaf flower eye table cake ball feather dragon bird border', 'caption': 'cake for little girl that loves brand .'}
# 6910
# {'objects': 'sky person sky bird bird bird water arm beach airplane duck wave duck ocean bird duck head water ground woman bird person beach sand woman bird beach wave sand bird', 'objects_no_rep': 'duck beach ocean sand head person wave airplane sky ground bird arm water woman', 'caption': 'chador clad women stand on an empty beach by sea .'}
# 6911
# {'objects': 'tripod toy tripod tile letter mixer table tile pipe name', 'objects_no_rep': 'tripod pipe tile name mixer table letter toy', 'caption': 'gold telescope isolated on a white background'}
# 6912
# {'objects': 'glass glass wine wine stem base label table stem wine bottle wine glass', 'objects_no_rep': 'label base stem table wine bottle glass', 'caption': 'wine in a traditional restaurant = delicious & dirt cheap .'}
# 6913
# {'objects': 'car car man sky tire truck car pant grass shirt car sign truck shirt shadow man pole traffic light car car shoe car grass sign van tree tire man door bicycle tire person road person tire pole man car parking lot light traffic light pant street light tail light window shadow tire car light', 'objects_no_rep': 'man shadow tail light pole traffic light pant street shirt bicycle car window shoe road tire person sign van sky parking lot door light tree truck grass', 'caption': 'the officer , an ambulance and a fire truck were headed east en route to a medical call when the crash occurred , according to police .'}
# 6914
# {'objects': 'man man car sky tie woman man scarf car head suit tree hand suit drawer skirt street door hand light person hair shoe car tree coat pant shirt handle jacket woman handle cloud hair tree light woman shoe suit car hand pole window jacket tree man hood tree sky tree head suit pant person lady cloud', 'objects_no_rep': 'scarf man handle pole woman street pant shirt jacket skirt car window shoe hood coat person hand suit sky cloud door light tree head drawer lady tie hair', 'caption': 'politicians get into a car following mass .'}
# 6915
# {'objects': 'nose animal mouth face paw eye eye monkey fur animal claw rock background foot head whisker', 'objects_no_rep': 'claw head whisker fur foot nose eye background face mouth rock monkey paw animal', 'caption': 'animal - the king of beasts'}
# 6916
# {'objects': 'water tire building tractor tire sky tire rim building tire pier boat wheel sign wheel pole number pipe', 'objects_no_rep': 'building tire water wheel pipe sign pole sky pier rim boat tractor number', 'caption': 'a fishing boat and a launching tractor on the beach in front of the pier .'}
# 6917
# {'objects': 'dress hand hand hair woman arm floor shoe head dress dress word word neck finger nose face word arm necklace word finger sleeve word mouth eye wall advertisement', 'objects_no_rep': 'floor wall head sleeve hand nose eye face finger advertisement neck hair mouth word shoe dress necklace arm woman', 'caption': 'dancer attends the launching party of new perfume as part .'}
# 6918
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
